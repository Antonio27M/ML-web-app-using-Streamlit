# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf
from pmdarima import auto_arima

# %% [markdown]
# ### Sistema de predicción de ventas
#
# Queremos establecer el almacén de nuestra empresa en otra localización y necesitamos estimar el ritmo de las ventas, que desde la creación de la empresa ha ido en aumento, para los próximos meses, a fin de proveer el espacio que necesitaremos.

# %%
df = pd.read_csv('/workspaces/Antonio27M-machine-learning/data/raw/internal-link-proyecto10.csv')

# %%
df.head()
# Out:
#                          date      sales
# 0  2022-09-03 17:10:08.079328  55.292157
# 1  2022-09-04 17:10:08.079328  53.803211
# 2  2022-09-05 17:10:08.079328  58.141693
# 3  2022-09-06 17:10:08.079328  64.530899
# 4  2022-09-07 17:10:08.079328  66.013633

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    366 non-null    object
#  1   sales   366 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 5.8+ KB

# %%
df["date"] = pd.to_datetime(df["date"])
df = df.sort_values("date")

# %%
df.dtypes
# Out:
# date     datetime64[ns]
# sales           float64
# dtype: object

# %%
df['date'].drop()

# %%
# Out:
# ---------------------------------------------------------------------------
# DateParseError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df['date'] = pd.to_datetime(arg='day', dayfirst=True)
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/tools/datetimes.py:1106, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1104         result = convert_listlike(argc, format)
#    1105 else:
# -> 1106     result = convert_listlike(np.array([arg]), format)[0]
#    1107     if isinstance(arg, bool) and isinstance(result, np.bool_):
#    1108         result = bool(result)  # TODO: avoid this kludge.
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/tools/datetimes.py:437, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     434 if format is not None and format != "mixed":
#     435     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
# --> 437 result, tz_parsed = objects_to_datetime64(
#     438     arg,
#     439     dayfirst=dayfirst,
#     440     yearfirst=yearfirst,
#     441     utc=utc,
#     442     errors=errors,
#     443     allow_object=True,
#     444 )
#     446 if tz_parsed is not None:
#     447     # We can take a shortcut since the datetime64 numpy array
#     448     # is in UTC
#     449     out_unit = np.datetime_data(result.dtype)[0]
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/arrays/datetimes.py:2415, in objects_to_datetime64(data, dayfirst, yearfirst, utc, errors, allow_object, out_unit)
#    2412 # if str-dtype, convert
#    2413 data = np.asarray(data, dtype=np.object_)
# -> 2415 result, tz_parsed = tslib.array_to_datetime(
#    2416     data,
#    2417     errors=errors,
#    2418     utc=utc,
#    2419     dayfirst=dayfirst,
#    2420     yearfirst=yearfirst,
#    2421     creso=abbrev_to_npy_unit(out_unit),
#    2422 )
#    2424 if tz_parsed is not None:
#    2425     # We can take a shortcut since the datetime64 numpy array
#    2426     #  is in UTC
#    2427     return result, tz_parsed
#
# File pandas/_libs/tslib.pyx:412, in pandas._libs.tslib.array_to_datetime()
#
# File pandas/_libs/tslib.pyx:596, in pandas._libs.tslib.array_to_datetime()
#
# File pandas/_libs/tslib.pyx:553, in pandas._libs.tslib.array_to_datetime()
#
# File pandas/_libs/tslibs/conversion.pyx:641, in pandas._libs.tslibs.conversion.convert_str_to_tsobject()
#
# File pandas/_libs/tslibs/parsing.pyx:336, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File pandas/_libs/tslibs/parsing.pyx:666, in pandas._libs.tslibs.parsing.dateutil_parse()
#
# DateParseError: Unknown datetime string format, unable to parse: day, at position 0
